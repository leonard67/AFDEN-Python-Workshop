# %% [markdown]
# ### Session 2 Homework
#
# Try to complete the following function of winsorizing by group (i.e., replicating the `winsor2` function in Stata):

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('comp_sample.csv', parse_dates=['datadate'])

# %%
def winsorize_by_group(df: pd.DataFrame, 
                       var: list[str], 
                       p: float = 0.01, 
                       truncate: bool = False, 
                       by: list|None = None) -> pd.DataFrame:
    
    '''Winsorize or truncate variables in a DataFrame, optionally by group.'''

    if p <= 0 or p >= 0.5:
        raise ValueError('p must be between 0 and 0.5')
    
    if by is None:
        if truncate:
            
        else:
            
    else:
        if truncate:
            
        else:
            
    
    return

# %%
# Check your function with:
df1 = winsorize_by_group(df = df, var=['at', 'ceq', 'ni'], truncate=True, by=['fyear'])
