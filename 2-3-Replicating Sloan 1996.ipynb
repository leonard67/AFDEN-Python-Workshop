# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_stata("data/Sloan_Raw.dta", convert_dates=['datadate', 'EA_date'])

# %% [markdown]
# ### Step 1. Prepare the dataset and variables

# %%
# Preprocess missing values

# %%
# delete financial and utility industries

# %%
# Define Accruals, CFO and earnings

# %%
# Drop rows with missing key variables

# %%
# Define Lagged and Future earnings

# %% [markdown]
# ### Step 2: Define Portfolios

# %%
# Ranking into deciles by year
qtls = [i + 1 for i in range(10)]

# %%
# Keep extreme deciles based on ACC

# %%
# Hedge portfolio returns (long lowest accrual decile, short highest)

# %% [markdown]
# ### Step 3: Draw the hedge return as in Figure 2 of Sloan (1996)

# %%
plt.figure(figsize=(8, 4.5))


plt.title('Hedge Portfolio Returns')
plt.xlabel('Year')
plt.ylabel('Return')
plt.show()
